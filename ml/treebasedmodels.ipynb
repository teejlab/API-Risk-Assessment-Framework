# %% [markdown]
# # Supervised Learning

# %% [markdown]
# In this notebook, we are going to attempt different tree-based supervised learning models. They are:
# - Decision Tree
# - Random Forest
# - CatBoost
# - XGBoost
# - LGMB

# %% [markdown]
# **Things to look into:**
# - Why is the model so perfect?
# - Is there something we are missing?
# **Things to do:**
# - edit the scoring metric to include recall and f1 (note: need to adjust it since our classification is multiclass)

# %% [markdown]
# # Load in the Dataset + Packages

# %%
# pip install graphviz
import sklearn
import graphviz 
from sklearn import tree
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from catboost import CatBoostClassifier
from lightgbm.sklearn import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    cross_val_score,
    cross_validate,
    train_test_split,
)
import pandas as pd
import matplotlib.pyplot as plt

# %%
#dataset
df = pd.read_excel("df_full_clean.xlsx", usecols = "A:BB")

#imputation of NRI score with mean value
df['NRI score']=df['NRI score'].replace(0, df['NRI score'].mean())

# %%
df['Risk_Label'] = df['Risk_Label'].astype('category')
df['Risk_Label']
# Out:
# 0       Low Risk
# 1       Low Risk
# 2       Low Risk
# 3       Low Risk
# 4         Medium
#           ...
# 1844      Medium
# 1845    Low Risk
# 1846    Low Risk
# 1847    Low Risk
# 1848      Medium
# Name: Risk_Label, Length: 1849, dtype: category
# Categories (3, object): ['High', 'Low Risk', 'Medium']

# %%
# dropped security_test_category
X = df.drop(columns = ['Risk_Label', 'security_test_category'])
y = df['Risk_Label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#       usage_base  authentication  server_name  is_pii  is_fii  NRI score  \
# 1625           2               1            1   False   False  76.479613
# 1038           2               1            1   False   False  19.643806
# 1752           2               1            1   False   False  81.089820
# 296            2               0            1   False   False  19.643806
# 855            2               1            1    True   False  19.643806
# ...          ...             ...          ...     ...     ...        ...
# 1695           2               1            0    True   False  81.089820
# 1201           2               1            1    True   False  19.643806
# 417            2               0            1    True   False  19.643806
# 816            2               1            1   False   False  19.643806
# 1077           2               1            1    True   False  19.643806
#
#       AI & Data Science  Business & Technology  Environment & Weather  \
# 1625                  0                      0                      0
# 1038                  0                      0                      0
# 1752                  0                      1                      0
# 296                   0                      0                      0
# 855                   0                      0                      0
# ...                 ...                    ...                    ...
# 1695                  0                      0                      0
# 1201                  0                      0                      0
# 417                   0                      0                      0
# 816                   0                      0                      0
# 1077                  0                      0                      0
#
#       Finance & Banking  ...  referrer-policy  content-type  set-cookie  \
# 1625                  0  ...                0             0           1
# 1038                  0  ...                0             1           0
# 1752                  0  ...                0             1           0
# 296                   0  ...                0             0           0
# 855                   0  ...                1             1           0
# ...                 ...  ...              ...           ...         ...
# 1695                  0  ...                0             0           0
# 1201                  0  ...                0             0           0
# 417                   0  ...                0             1           0
# 816                   0  ...                0             0           1
# 1077                  0  ...                0             0           1
#
#       access-control-allow-origin  server  x-powered-by  x-aspnet-version  \
# 1625                            1       1             1                 0
# 1038                            0       1             1                 0
# 1752                            1       1             0                 0
# 296                             1       0             0                 0
# 855                             0       0             0                 0
# ...                           ...     ...           ...               ...
# 1695                            0       1             1                 0
# 1201                            1       1             1                 0
# 417                             1       0             0                 0
# 816                             0       1             1                 1
# 1077                            1       1             1                 0
#
#       x-ratelimit-limit  metadata_fields_count  parameters_count
# 1625                  0                      5                 0
# 1038                  0                      3                 1
# 1752                  0                      3                 2
# 296                   0                      3                 0
# 855                   0                      5                 1
# ...                 ...                    ...               ...
# 1695                  0                      3                 1
# 1201                  0                      6                 3
# 417                   0                      4                 1
# 816                   0                      5                 2
# 1077                  0                      6                 5
#
# [1479 rows x 52 columns]

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %% [markdown]
# ## 1. Decision Tree

# %% [markdown]
# ### Basic Approach

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
clf = tree.DecisionTreeClassifier(random_state=37, max_depth=6, criterion='entropy')

# %%
clf = clf.fit(X_train,y_train)

# %%
clf.predict(X_test)
# Out:
# array(['Medium', 'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk',
#        'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Medium', 'Low Risk',
#        'Low Risk', 'Low Risk', 'High', 'Medium', 'Medium', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Medium', 'Medium', 'Medium', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Medium', 'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk',
#        'Medium', 'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Medium',
#        'Medium', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Medium', 'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Medium', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Medium',
#        'Medium', 'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Low Risk',
#        'Medium', 'Medium', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'High',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Medium',
#        'Low Risk', 'Low Risk', 'Medium', 'High', 'Low Risk', 'Low Risk',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low Risk',
#        'Medium', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low Risk', 'High', 'Low Risk', 'Low Risk',
#        'Medium', 'Medium', 'Low Risk', 'High', 'Low Risk', 'Low Risk',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk',
#        'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Medium', 'Medium',
#        'Medium', 'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Medium', 'Medium',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Low Risk',
#        'Medium', 'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk',
#        'Low Risk', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'High', 'Low Risk', 'Medium', 'Low Risk',
#        'Medium', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Medium'], dtype=object)

# %%
# Visualise the tree
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize=(12,12))
fn = list(X_train)
cn = list(y_train)
tree.plot_tree(clf, 
              feature_names = fn,
              class_names = cn,
              fontsize=10)
fig.savefig('trial.png')

# %%
# Alternative visualisation
visualise_tree = tree.export_graphviz(clf, out_file=None,
                                      feature_names = fn,
                                      class_names = cn)
graph = graphviz.Source(visualise_tree)
graph
# See here for more [https://scikit-learn.org/stable/modules/tree.html]

# %%
y_pred = clf.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9783783783783784

# %% [markdown]
# ### Various hyperparameters to attempt

# %%
# max depth
clf_maxdepth = DecisionTreeClassifier(random_state=37, max_depth=5)
clf_maxdepth = clf_maxdepth.fit(X_train,y_train)
y_pred = clf_maxdepth.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9783783783783784

# %%
# max_leaf_nodes
clf_maxleafnode = DecisionTreeClassifier(random_state=37, max_leaf_nodes=5)
clf_maxleafnode = clf_maxleafnode.fit(X_train,y_train)
y_pred = clf_maxleafnode.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9783783783783784

# %% [markdown]
# ## 2. Random Forest

# %% [markdown]
# ### Basic Approach

# %%
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" % (mean_scores[i], std_scores[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %%
scoring_metric = ["accuracy"]
results = {}

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
rf_clf = RandomForestClassifier(n_estimators=100, random_state=37, n_jobs=-1) # n_estimators = no. of trees in the forest
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=37)

# %%
results["Random forests"] = mean_std_cross_val_scores(
    rf_clf, X_train, y_train, return_train_score=True, scoring=scoring_metric
)
pd.DataFrame(results).T
# Out:
#                          fit_time         score_time      test_accuracy  \
# Random forests  0.329 (+/- 0.479)  0.021 (+/- 0.001)  0.980 (+/- 0.005)
#
#                    train_accuracy
# Random forests  0.991 (+/- 0.001)

# %%
# rf_clf(X_test)

# %%
# print("Accuracy:", metrics.accuracy_score(y_test, y_pred_rf_clf))

# %%
# feature importance
# feature_imp = pd.Series(rf_clf.feature_importances_, 
                        # index = X_train.feature_names).sort_values(ascending = False)
# feature_imp

# %% [markdown]
# ### Various hyperparameters to attempt

# %%
# random_grid = {'bootstrap': [True, False],
#                'max_depth': [2, 4, 6, 8, 10, 12, None],
#                'max_features': ['auto', 'sqrt'],
#                'min_samples_leaf': [1, 2, 4],
#                'min_samples_split': [2, 5, 10],
#                'n_estimators': [130, 180, 230]}

# %%
# scoring_metric = ["accuracy"]
# rf_random = RandomizedSearchCV(estimator = rf, 
#                                param_distributions = random_grid, 
#                                n_iter = 100, 
#                                cv = 3, 
#                                verbose=2, 
#                                random_state=37, 
#                                n_jobs = -1,
#                                scoring = scoring_metric,
#                                return_train_score=True)

# %%
# rf_random.fit(X_train, y_train)

# %%
# cv_results = rf_random.cv_results_
# for mean_score, params in zip(cv_results["mean_test_score"], cvres["params"]):
#     print(np.sqrt(-mean_score), params)

# %%
# find best params
# best_params = rf_random.best_params_
# best_params

# %%
# best score
# rf_random.best_score_

# %%
# df_rf_random = pd.DataFrame(rf_random.cv_results_)
# df_rf_random

# %% [markdown]
# ## 3. All the boosts

# %% [markdown]
# ### Reference:
# https://pages.github.ubc.ca/mds-2021-22/DSCI_573_feat-model-select_students/lectures/05_ensembles.html

# %%
classifiers = {
    "CatBoost": CatBoostClassifier(verbose=0, random_state=37),
    "XGBoost": XGBClassifier(random_state=37, eval_metric='logloss', verbosity=0),
    "LightGBM": LGBMClassifier(random_state=37),
    "decision tree": DecisionTreeClassifier(random_state=37),
    "random forest": RandomForestClassifier(n_estimators=100, random_state=37)
}

# %%
results = {}
scoring_metric = ["accuracy"]

# %%
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" % (mean_scores[i], std_scores[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %%
dummy = DummyClassifier(strategy="stratified")
results["Dummy"] = mean_std_cross_val_scores(
    dummy, X, y, return_train_score=True, scoring=scoring_metric
)

# %%
for (name, model) in classifiers.items():
    results[name] = mean_std_cross_val_scores(
        model, X, y, return_train_score=True, scoring=scoring_metric
    )
# Out:
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/sklearn.py", line 967, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/sklearn.py", line 748, in fit
#     self._Booster = train(
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/engine.py", line 271, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/basic.py", line 2605, in __init__
#     train_set.construct()
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/basic.py", line 1815, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/basic.py", line 1573, in _lazy_init
#     return self.set_feature_name(feature_name)
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/basic.py", line 2142, in set_feature_name
#     _safe_call(_LIB.LGBM_DatasetSetFeatureNames(
#   File "/opt/miniconda3/envs/573/lib/python3.9/site-packages/lightgbm/basic.py", line 125, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
# lightgbm.basic.LightGBMError: Do not support special JSON characters in feature name.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
pd.DataFrame(results).T
# Out:
#                         fit_time         score_time      test_accuracy  \
# Dummy          0.004 (+/- 0.002)  0.001 (+/- 0.000)  0.478 (+/- 0.032)
# CatBoost       2.073 (+/- 0.123)  0.005 (+/- 0.000)  0.975 (+/- 0.030)
# XGBoost        0.510 (+/- 0.081)  0.005 (+/- 0.000)  0.976 (+/- 0.027)
# LightGBM       0.012 (+/- 0.001)  0.000 (+/- 0.000)      nan (+/- nan)
# decision tree  0.011 (+/- 0.000)  0.003 (+/- 0.000)  0.975 (+/- 0.032)
# random forest  0.146 (+/- 0.010)  0.013 (+/- 0.000)  0.976 (+/- 0.026)
#
#                   train_accuracy
# Dummy          0.493 (+/- 0.017)
# CatBoost       0.988 (+/- 0.007)
# XGBoost        0.988 (+/- 0.007)
# LightGBM           nan (+/- nan)
# decision tree  0.988 (+/- 0.007)
# random forest  0.988 (+/- 0.007)
