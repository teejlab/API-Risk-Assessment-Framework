# %% [markdown]
# # Supervised Learning

# %% [markdown]
# In this notebook, we are going to attempt different tree-based supervised learning models. They are:
# - Decision Tree
# - Random Forest
# - CatBoost
# - XGBoost
# - LGMB

# %% [markdown]
# **Things to look into:**
# - Why is the model so perfect?
# - Is there something we are missing?
# **Things to do:**
# - edit the scoring metric to include recall and f1 (note: need to adjust it since our classification is multiclass)

# %% [markdown]
# # Load in the Dataset + Packages

# %%
# pip install graphviz
import sklearn
import graphviz 
from sklearn import tree
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from catboost import CatBoostClassifier
from lightgbm.sklearn import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    cross_val_score,
    cross_validate,
    train_test_split,
)
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#dataset
# df = pd.read_excel("df_full_clean.xlsx", usecols = "A:BB")
df = pd.read_excel("smote.xlsx", usecols = "A:BA")


#imputation of NRI score with mean value
df['NRI score'] = df['NRI score'].replace(0, np.NaN)
df['NRI score'] = df['NRI score'].replace(np.NaN, df['NRI score'].mean())

# %%
df['NRI score'].mean()
# Out:
# 74.69000150711354

# %%
df['NRI score'].unique()
# Out:
# array([8.10898203e+01, 7.64796134e+01, 7.46900015e+01, 7.89453554e+01,
#        8.20616375e+01, 7.65981869e+01, 7.22550478e+01, 7.49625191e+01,
#        4.97445967e+01, 7.37891479e+01, 8.15679290e+01, 7.47907437e+01,
#        6.99428590e+01, 4.09287916e+01, 8.00144209e+01, 5.77440389e+01,
#        6.68975472e+01, 7.97046319e+01, 1.35006525e+00, 3.02574461e+01,
#        7.85332743e+01, 7.84390977e+01, 7.48955242e+01, 7.98244949e+01,
#        5.27572774e+01, 8.02263746e+01, 6.42946409e+01, 1.72930673e+01,
#        7.95277424e+01, 7.76464254e+01, 1.31705350e+01, 6.58112836e+01,
#        7.66715108e+01, 4.99594734e+01, 8.03824712e+01, 6.03864819e+01,
#        8.02899764e+01, 5.08731465e+01, 7.69517429e+01, 6.76484782e+01,
#        3.41055772e+01, 7.78220537e+01, 8.00462086e+01, 4.23877542e+01,
#        7.88087317e+01, 7.88577502e+01, 7.87869636e+01, 4.42207621e+01,
#        7.81091391e+01, 7.71602242e+01, 1.64731245e+00, 1.89671320e+01,
#        8.09437931e+01, 7.65864483e+01, 7.95639655e+01, 5.41580826e+01,
#        5.10669180e+00, 7.57911303e+01, 6.92076943e+01, 2.47852234e+00,
#        3.36014841e+01, 8.07209023e+01, 7.23138608e+01, 6.26927754e+01,
#        7.61849877e+01, 7.94030782e+01, 8.10596306e+01, 7.92247944e+01,
#        6.92359909e+01, 4.76425291e+01, 6.12594395e+01, 7.66795358e+01,
#        2.41810739e+01, 8.08989993e+01, 1.90817272e+01, 7.90582497e+01,
#        7.73196627e+01, 4.32778950e+01, 4.41207036e+01, 5.38656910e+01,
#        5.62936918e+01, 8.05465033e+01, 7.68988513e+01, 4.30866153e+01,
#        6.82016443e+01, 5.04935811e+01, 2.21086018e+01, 7.79686228e+01,
#        7.68898855e+01, 7.72419371e+01, 7.94812695e+01, 3.08604223e+01,
#        7.73738621e+01, 5.80198525e+01, 7.72840302e+01, 7.90306939e+01,
#        7.99583556e+01, 7.86946781e+01, 3.12085863e+00, 1.62703040e+00,
#        4.07019991e+01, 1.79870949e+01, 6.97936821e+01, 6.97573002e+01,
#        4.84233814e+01, 4.62167777e+01, 4.74788665e+01, 8.02152815e+01,
#        6.90968775e+01, 7.33942058e+01, 8.08463985e+01, 7.59754640e+01,
#        2.14223269e+00, 8.00813585e+01, 6.25237477e+01, 4.57350953e+01,
#        8.06300876e+01, 7.89732694e+01, 2.05499214e+01, 7.96656717e+01,
#        3.37943097e+01, 7.67995457e+01, 7.81948398e+01, 7.84572370e+01,
#        5.51570166e+01, 6.43567493e+01, 7.17126656e+01, 8.01684972e+01,
#        8.01225860e+01, 2.52571992e+01, 8.05829976e+01, 7.79403617e+01,
#        7.20491785e+01, 7.19791704e+01, 7.02791444e+01, 8.06748808e+01,
#        6.65344185e+01, 4.25937207e+01, 7.99963181e+01, 7.80446350e+01,
#        4.81764736e+01, 7.65623402e+01, 7.77477616e+01, 6.40003596e+01,
#        7.99271107e+01, 2.21412102e+01, 4.52781021e+00, 8.07206025e+01,
#        7.85378267e+01, 7.92959995e+01, 7.73114846e+01, 7.67385265e+01,
#        3.71288631e+01, 5.78263070e+01, 4.55961543e+01, 7.97213105e+01,
#        1.35168433e+01, 6.08741068e+01, 1.06725116e+01, 7.66621965e+01,
#        1.73310363e+01, 5.18485856e+01, 6.13815743e+01, 2.36759455e+01,
#        5.96452583e+01, 1.80439231e+01, 7.67661425e+01, 7.91290511e+01,
#        1.87933081e+01, 8.09700887e+01, 6.78437956e+01, 2.02146248e+01,
#        1.68288067e+01, 8.08526199e+01, 4.82422087e+01, 7.88556131e+01,
#        1.33650580e+01, 7.65209556e+01, 4.65022910e+01, 7.65672601e+01,
#        7.34027862e+01, 5.12061675e+01, 7.91797149e+01, 7.92522096e+01,
#        6.95922345e+01, 7.75686648e+01, 7.92939047e+01, 4.37052774e+01,
#        7.99836380e+01, 7.91402216e+01, 7.65437057e+01, 5.20786422e+01,
#        7.65578154e+01, 7.58838850e+00, 8.00324917e+01, 7.11736874e+01,
#        5.12089388e+00, 6.80591860e+01, 7.79271540e+01, 4.52824145e+01,
#        8.02405571e+01, 8.01706155e+01, 8.05877526e+01, 7.79179930e+01,
#        7.71345996e+01, 3.58284315e+01, 7.98772997e-02, 3.36810896e+01,
#        1.36783121e+01, 7.11796657e+01, 8.09903822e+01, 7.95327789e+01,
#        1.89279511e+01, 7.98037006e+01, 7.66811022e+01, 7.83327785e+01,
#        7.71022754e+01, 1.09267059e+01, 7.70916170e+01, 8.09843042e+01,
#        7.77181746e+01, 7.99707967e+01, 8.04040223e+01, 6.56955436e+01,
#        3.09551927e+01, 7.65770436e+01, 8.09901541e+01, 7.97290367e+01,
#        4.72868076e+01, 7.94346002e+01, 7.75028951e+01, 8.04935620e+01,
#        5.98834929e+01, 4.56748865e+00, 6.32231176e+01, 3.20513593e+01,
#        8.05224522e+01, 7.75793544e+01, 7.91339829e+01, 2.86872221e+01,
#        4.02981839e+01, 3.06315134e+01, 7.67098255e+01, 7.85883545e+01,
#        8.06287903e+01, 5.34076326e+01, 5.19599822e+01, 5.33414472e+01,
#        7.66038314e+01, 2.83329718e+01, 7.66648737e+01, 4.09863819e+01,
#        7.76732903e+01, 2.99984077e+01, 7.12152310e+01, 7.69983413e+01,
#        7.96163541e+01, 7.72946794e+01, 8.03713561e+01, 6.57367779e+01,
#        7.57063391e+01, 7.77276303e+01, 7.95268319e+01, 1.29211306e+01,
#        7.89768364e+01, 8.00875701e+01, 1.92575202e+01, 7.96598923e+01,
#        7.66863793e+01, 1.74468729e+01, 8.00381792e+01])

# %%
df['Risk_Label'] = df['Risk_Label'].astype('category')
df['Risk_Label']
# Out:
# 0       Low Risk
# 1       Low Risk
# 2       Low Risk
# 3       Low Risk
# 4         Medium
#           ...
# 2878    Low Risk
# 2879    Low Risk
# 2880    Low Risk
# 2881    Low Risk
# 2882    Low Risk
# Name: Risk_Label, Length: 2883, dtype: category
# Categories (3, object): ['High', 'Low Risk', 'Medium']

# %%
# dropped security_test_category
X = df.drop(columns = ['Risk_Label'])
y = df['Risk_Label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#       usage_base  authentication  server_name  is_pii  is_fii  NRI score  \
# 1986           2               1            1   False   False  81.089820
# 1904           2               1            0    True    True  13.170535
# 1353           2               1            1   False   False  81.089820
# 2655           2               1            0   False   False  80.493562
# 652            2               1            1    True   False  74.690002
# ...          ...             ...          ...     ...     ...        ...
# 332            2               0            1   False   False  74.690002
# 1124           2               1            1    True   False  76.479613
# 563            2               1            1    True   False  74.690002
# 1480           2               1            1   False   False  74.690002
# 1987           2               1            0   False   False  76.586448
#
#       AI & Data Science  Business & Technology  Environment & Weather  \
# 1986                  0                      0                      0
# 1904                  0                      0                      0
# 1353                  1                      0                      0
# 2655                  0                      0                      0
# 652                   0                      0                      0
# ...                 ...                    ...                    ...
# 332                   0                      0                      0
# 1124                  0                      0                      0
# 563                   0                      0                      0
# 1480                  0                      0                      0
# 1987                  0                      0                      0
#
#       Finance & Banking  ...  referrer-policy  content-type  set-cookie  \
# 1986                  0  ...                0             0           0
# 1904                  0  ...                0             0           0
# 1353                  0  ...                0             1           1
# 2655                  0  ...                0             0           0
# 652                   0  ...                0             0           0
# ...                 ...  ...              ...           ...         ...
# 332                   0  ...                0             1           0
# 1124                  0  ...                0             0           1
# 563                   0  ...                0             0           0
# 1480                  0  ...                0             0           0
# 1987                  0  ...                0             0           0
#
#       access-control-allow-origin  server  x-powered-by  x-aspnet-version  \
# 1986                            0       1             1                 0
# 1904                            0       0             0                 0
# 1353                            1       1             0                 0
# 2655                            0       0             1                 0
# 652                             0       1             1                 0
# ...                           ...     ...           ...               ...
# 332                             0       1             0                 0
# 1124                            1       1             0                 0
# 563                             0       0             0                 0
# 1480                            1       1             0                 0
# 1987                            0       0             1                 0
#
#       x-ratelimit-limit  metadata_fields_count  parameters_count
# 1986                  0                      3                 3
# 1904                  0                      0                 0
# 1353                  0                      4                 2
# 2655                  0                      3                 2
# 652                   0                      3                 0
# ...                 ...                    ...               ...
# 332                   0                      4                 2
# 1124                  0                      7                 3
# 563                   0                      0                 0
# 1480                  0                      5                 1
# 1987                  0                      3                 2
#
# [2306 rows x 52 columns]

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %% [markdown]
# ## 1. Decision Tree

# %% [markdown]
# ### Basic Approach

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
clf = tree.DecisionTreeClassifier(random_state=37, criterion='gini')

# %%
clf = clf.fit(X_train,y_train)

# %%
clf.predict(X_test)
# Out:
# array(['Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium',
#        'Low Risk', 'Low Risk', 'High', 'Medium', 'Medium', 'High', 'High',
#        'Low Risk', 'Low Risk', 'High', 'Low Risk', 'Medium', 'High',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'High', 'Medium',
#        'High', 'High', 'Low Risk', 'Medium', 'High', 'Low Risk', 'High',
#        'Medium', 'Low Risk', 'High', 'Low Risk', 'Low Risk', 'High',
#        'Low Risk', 'Low Risk', 'Low Risk', 'High', 'Medium', 'Medium',
#        'Medium', 'High', 'Low Risk', 'Medium', 'High', 'Low Risk',
#        'Low Risk', 'High', 'Medium', 'Low Risk', 'Medium', 'High',
#        'Medium', 'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'Medium',
#        'Low Risk', 'High', 'High', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'High', 'Low Risk', 'High', 'High', 'Medium',
#        'Low Risk', 'Medium', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'High', 'Low Risk',
#        'Low Risk', 'High', 'Low Risk', 'Low Risk', 'High', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'Medium', 'High', 'Low Risk',
#        'Medium', 'High', 'Low Risk', 'Low Risk', 'High', 'High',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Medium', 'High', 'Low Risk',
#        'High', 'Low Risk', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Low Risk', 'Low Risk', 'High', 'Low Risk', 'High', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'High', 'High', 'High', 'High',
#        'High', 'Medium', 'High', 'Medium', 'Low Risk', 'Low Risk', 'High',
#        'High', 'High', 'Low Risk', 'Medium', 'Medium', 'High', 'Medium',
#        'Medium', 'Medium', 'Low Risk', 'Medium', 'High', 'Medium',
#        'Low Risk', 'Low Risk', 'High', 'Low Risk', 'High', 'Low Risk',
#        'Medium', 'High', 'High', 'High', 'Low Risk', 'Low Risk', 'High',
#        'High', 'High', 'High', 'High', 'High', 'Medium', 'High',
#        'Low Risk', 'High', 'Medium', 'High', 'Low Risk', 'High', 'High',
#        'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'High', 'Low Risk',
#        'Medium', 'High', 'Medium', 'Medium', 'Medium', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Low Risk', 'High',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Low Risk',
#        'Low Risk', 'Medium', 'Low Risk', 'Medium', 'Low Risk', 'High',
#        'Low Risk', 'High', 'Medium', 'Low Risk', 'High', 'Medium', 'High',
#        'High', 'High', 'High', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'High', 'Medium', 'High', 'Low Risk', 'Medium', 'High',
#        'High', 'High', 'High', 'Medium', 'High', 'Medium', 'Low Risk',
#        'High', 'High', 'Low Risk', 'Low Risk', 'High', 'Medium', 'Medium',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Low Risk',
#        'Low Risk', 'Medium', 'Medium', 'High', 'Medium', 'High',
#        'Low Risk', 'Medium', 'Medium', 'Medium', 'High', 'Low Risk',
#        'Low Risk', 'High', 'Medium', 'High', 'Low Risk', 'Low Risk',
#        'High', 'Low Risk', 'High', 'Medium', 'High', 'Low Risk', 'High',
#        'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'Medium', 'High',
#        'Medium', 'Medium', 'Medium', 'High', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low Risk', 'High', 'High', 'High', 'Medium',
#        'High', 'Medium', 'High', 'Low Risk', 'High', 'High', 'Medium',
#        'Low Risk', 'Medium', 'Medium', 'High', 'Low Risk', 'Medium',
#        'Low Risk', 'Low Risk', 'High', 'High', 'Medium', 'Medium', 'High',
#        'Medium', 'Medium', 'Medium', 'Medium', 'High', 'Low Risk', 'High',
#        'High', 'Medium', 'High', 'Low Risk', 'Low Risk', 'High',
#        'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'Low Risk', 'High',
#        'High', 'Medium', 'High', 'Low Risk', 'Medium', 'Medium', 'Medium',
#        'Low Risk', 'Medium', 'High', 'Medium', 'Low Risk', 'Low Risk',
#        'Medium', 'High', 'Low Risk', 'Medium', 'Medium', 'High',
#        'Low Risk', 'High', 'High', 'High', 'Low Risk', 'Low Risk', 'High',
#        'High', 'High', 'Medium', 'Low Risk', 'Low Risk', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Low Risk', 'High', 'High', 'Medium',
#        'High', 'Medium', 'Medium', 'Medium', 'Low Risk', 'Low Risk',
#        'Medium', 'Low Risk', 'Low Risk', 'High', 'Low Risk', 'Low Risk',
#        'Medium', 'Low Risk', 'Low Risk', 'High', 'Low Risk', 'High',
#        'Low Risk', 'High', 'High', 'Medium', 'Low Risk', 'High',
#        'Low Risk', 'Low Risk', 'High', 'Medium', 'High', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'High', 'Low Risk',
#        'High', 'Medium', 'High', 'High', 'Low Risk', 'High', 'Low Risk',
#        'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk', 'High',
#        'Low Risk', 'Low Risk', 'High', 'Medium', 'Medium', 'High', 'High',
#        'Medium', 'High', 'High', 'Medium', 'High', 'High', 'Medium',
#        'High', 'Medium', 'Medium', 'Medium', 'Low Risk', 'High',
#        'Low Risk', 'Medium', 'High', 'Low Risk', 'High', 'High', 'Medium',
#        'High', 'Low Risk', 'High', 'Medium', 'High', 'High', 'High',
#        'High', 'High', 'High', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Medium',
#        'Medium', 'High', 'Low Risk', 'High', 'High', 'High', 'High',
#        'High', 'Medium', 'Low Risk', 'Medium', 'High', 'Medium', 'Medium',
#        'High', 'Low Risk', 'Low Risk', 'High', 'Medium', 'Medium', 'High',
#        'High', 'Medium', 'High', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'High', 'Low Risk', 'Medium', 'Low Risk',
#        'High', 'Low Risk', 'Medium', 'Medium', 'High', 'Medium',
#        'Low Risk', 'Medium', 'High', 'High', 'Medium', 'Low Risk',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Medium',
#        'Low Risk', 'Medium', 'Low Risk', 'Medium', 'Medium', 'Low Risk',
#        'High', 'Low Risk', 'Medium', 'Low Risk', 'High', 'Low Risk',
#        'Medium', 'Low Risk', 'Low Risk', 'Medium', 'High', 'Medium',
#        'Low Risk', 'Medium', 'High', 'Medium', 'High', 'High', 'Low Risk',
#        'Low Risk', 'High', 'Low Risk', 'Medium', 'Medium', 'High', 'High',
#        'Low Risk', 'Low Risk', 'Medium', 'Medium', 'Low Risk', 'Low Risk',
#        'Medium', 'High', 'Low Risk', 'Medium', 'High', 'Medium',
#        'Low Risk', 'Low Risk', 'Medium', 'Low Risk', 'Low Risk'],
#       dtype=object)

# %%
# Visualise the tree
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize=(25,12))
fn = list(X_train)
cn = list(y_train)
tree.plot_tree(clf, 
              feature_names = fn,
              class_names = cn,
              fontsize=10,
              filled=True)
fig.savefig('trial.png')

# %%
# Alternative visualisation
visualise_tree = tree.export_graphviz(clf, out_file=None,
                                      feature_names = fn,
                                      class_names = cn,
                                     filled=True)
graph = graphviz.Source(visualise_tree)
graph

# See here for more [https://scikit-learn.org/stable/modules/tree.html]

# %%
y_pred = clf.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9878682842287695

# %% [markdown]
# ### Various hyperparameters to attempt

# %%
# max depth
clf_maxdepth = DecisionTreeClassifier(random_state=37, max_depth=5)
clf_maxdepth = clf_maxdepth.fit(X_train,y_train)
y_pred = clf_maxdepth.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9878682842287695

# %%
# max_leaf_nodes
clf_maxleafnode = DecisionTreeClassifier(random_state=37, max_leaf_nodes=5)
clf_maxleafnode = clf_maxleafnode.fit(X_train,y_train)
y_pred = clf_maxleafnode.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9601386481802426

# %% [markdown]
# ## 2. Random Forest

# %% [markdown]
# ### Basic Approach

# %%
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" % (mean_scores[i], std_scores[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %%
scoring_metric = ["accuracy", "f1_weighted"]
results = {}

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
rf_clf = RandomForestClassifier(n_estimators=100, random_state=37, n_jobs=-1) # n_estimators = no. of trees in the forest
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=37)

# %%
results["Random forests"] = mean_std_cross_val_scores(
    rf_clf, X_train, y_train, return_train_score=True, scoring=scoring_metric
)
pd.DataFrame(results).T
# Out:
#                          fit_time         score_time      test_accuracy  \
# Random forests  0.532 (+/- 0.795)  0.028 (+/- 0.001)  0.987 (+/- 0.003)
#
#                    train_accuracy   test_f1_weighted  train_f1_weighted
# Random forests  0.994 (+/- 0.001)  0.987 (+/- 0.003)  0.994 (+/- 0.001)

# %%
# rf_clf(X_test)

# %%
# print("Accuracy:", metrics.accuracy_score(y_test, y_pred_rf_clf))

# %%
# feature importance
# feature_imp = pd.Series(rf_clf.feature_importances_, 
                        # index = X_train.feature_names).sort_values(ascending = False)
# feature_imp

# %% [markdown]
# ### Various hyperparameters to attempt

# %%
# random_grid = {'bootstrap': [True, False],
#                'max_depth': [2, 4, 6, 8, 10, 12, None],
#                'max_features': ['auto', 'sqrt'],
#                'min_samples_leaf': [1, 2, 4],
#                'min_samples_split': [2, 5, 10],
#                'n_estimators': [130, 180, 230]}

# %%
# scoring_metric = ["accuracy"]
# rf_random = RandomizedSearchCV(estimator = rf, 
#                                param_distributions = random_grid, 
#                                n_iter = 100, 
#                                cv = 3, 
#                                verbose=2, 
#                                random_state=37, 
#                                n_jobs = -1,
#                                scoring = scoring_metric,
#                                return_train_score=True)

# %%
# rf_random.fit(X_train, y_train)

# %%
# cv_results = rf_random.cv_results_
# for mean_score, params in zip(cv_results["mean_test_score"], cvres["params"]):
#     print(np.sqrt(-mean_score), params)

# %%
# find best params
# best_params = rf_random.best_params_
# best_params

# %%
# best score
# rf_random.best_score_

# %%
# df_rf_random = pd.DataFrame(rf_random.cv_results_)
# df_rf_random

# %% [markdown]
# ## 3. All the boosts

# %% [markdown]
# ### Reference:
# https://pages.github.ubc.ca/mds-2021-22/DSCI_573_feat-model-select_students/lectures/05_ensembles.html

# %%
classifiers = {
    "CatBoost": CatBoostClassifier(verbose=0, random_state=37),
    "XGBoost": XGBClassifier(random_state=37, eval_metric='logloss', verbosity=0),
    # "LightGBM": LGBMClassifier(random_state=37),
    "Decision Tree": DecisionTreeClassifier(random_state=37),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=37)
}

# %%
results = {}
scoring_metric = ["accuracy", "f1_macro", "recall_macro"]

# %%
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" % (mean_scores[i], std_scores[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %%
dummy = DummyClassifier(strategy="stratified")
results["Dummy"] = mean_std_cross_val_scores(
    dummy, X, y, return_train_score=True, scoring=scoring_metric
)

# %%
for (name, model) in classifiers.items():
    results[name] = mean_std_cross_val_scores(
        model, X, y, return_train_score=True, scoring=scoring_metric
    )
# Out:
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/miniconda3/envs/573/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
pd.DataFrame(results).T
# Out:
#                         fit_time         score_time      test_accuracy  \
# Dummy          0.003 (+/- 0.004)  0.009 (+/- 0.005)  0.328 (+/- 0.012)
# CatBoost       2.903 (+/- 0.344)  0.012 (+/- 0.001)  0.985 (+/- 0.021)
# XGBoost        0.968 (+/- 0.197)  0.015 (+/- 0.002)  0.984 (+/- 0.025)
# Decision Tree  0.016 (+/- 0.003)  0.011 (+/- 0.002)  0.974 (+/- 0.036)
# Random Forest  0.176 (+/- 0.013)  0.024 (+/- 0.008)  0.983 (+/- 0.022)
#
#                   train_accuracy      test_f1_macro     train_f1_macro  \
# Dummy          0.334 (+/- 0.011)  0.328 (+/- 0.011)  0.334 (+/- 0.011)
# CatBoost       0.991 (+/- 0.005)  0.985 (+/- 0.021)  0.991 (+/- 0.005)
# XGBoost        0.991 (+/- 0.005)  0.984 (+/- 0.024)  0.991 (+/- 0.005)
# Decision Tree  0.992 (+/- 0.005)  0.974 (+/- 0.036)  0.992 (+/- 0.005)
# Random Forest  0.992 (+/- 0.005)  0.983 (+/- 0.022)  0.992 (+/- 0.005)
#
#                test_recall_macro train_recall_macro
# Dummy          0.328 (+/- 0.012)  0.334 (+/- 0.011)
# CatBoost       0.985 (+/- 0.021)  0.991 (+/- 0.005)
# XGBoost        0.984 (+/- 0.025)  0.991 (+/- 0.005)
# Decision Tree  0.974 (+/- 0.036)  0.992 (+/- 0.005)
# Random Forest  0.983 (+/- 0.022)  0.992 (+/- 0.005)
