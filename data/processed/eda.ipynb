# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import openpyxl

# %% [markdown]
# ## Read in excel file to pandas

# %%
api_df = pd.read_excel("../raw/RiskClassification_Data_Endpoints_V1.xlsx", "Core_Endpoint",
                      usecols = "A:R")
api_df
# Out:
#       api_endpoint_id  api_id  api_vendor_id  api_vendor                  api  \
# 0                2410    1045            361     OneLook  Datamuse Dictionary
# 1                2410    1045            361     OneLook  Datamuse Dictionary
# 2                2410    1045            361     OneLook  Datamuse Dictionary
# 3                2410    1045            361     OneLook  Datamuse Dictionary
# 4                2410    1045            361     OneLook  Datamuse Dictionary
# ...               ...     ...            ...         ...                  ...
# 1995             2823    1286            574  TestVendor        DepartmentAPI
# 1996             2823    1286            574  TestVendor        DepartmentAPI
# 1997             2823    1286            574  TestVendor        DepartmentAPI
# 1998             2823    1286            574  TestVendor        DepartmentAPI
# 1999             2823    1286            574  TestVendor        DepartmentAPI
#
# ...
