# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import openpyxl
from matplotlib import pyplot as plt
import spacy
import seaborn as sns
import altair as alt
alt.renderers.enable('mimetype')
# Out:
# RendererRegistry.enable('mimetype')

# %% [markdown]
# ## Load both Teejlab and country data

# %%
# Teejlab data
api_df = pd.read_excel("../data/raw/RiskClassification_Data_Endpoints_V2.xlsx", "Core_Endpoint",
                      usecols = "A:R")
api_df.head()
# Out:
#    api_endpoint_id  api_id  api_vendor_id                   api  request_id  \
# 0             2513    1117            411             Tenor API        7629
# 1             2578    1148            440          ANZ Products        8698
# 2             2575    1147            439         NAB Open APIs        8542
# 3             2516    1119            413        Translate Text        7733
# 4             2416    1050            365  Google Custom Search       24061
#
#   method             category  \
# 0    get         News & Media
# 1    get    Finance & Banking
# 2    get    Finance & Banking
# 3    get    AI & Data Science
# 4    get  Software & Services
#
#                                           parameters usage_base  \
# 0                                   {"q": "Running"}       free
# 1                                                 {}       free
# 2                                         {"v": "1"}       free
# 3  {"lang": "en-zh", "text": "GNE is a good schoo...       free
# 4                       {"q": "Dehri, Bihar, India"}       free
#
#                                      sample_response  \
# 0  {\n  "weburl": "https://tenor.com/search/runni...
# 1  {"data":{"products":[{"additionalInformation":...
# 2  <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...
# 3  {"code":200,"lang":"en-zh","text":["ç½‘å…³ç½‘å...
# 4  {\n  "kind": "customsearch#search",\n  "url": ...
#
#                                               tagset authentication  \
# 0                                                NaN            NaN
# 1  links,eligibilityUri,brand,next,overviewUri,da...         header
# 2                                                NaN         header
# 3            lang,code,text,text,text,text,text,text          query
# 4  template,snippet,safe,type,url,items,cacheId,h...          query
#
#   security_test_category  security_test_result (FALSE=Passed; TRUE=Failed)  \
# 0                    NaN                                               NaN
# 1                    NaN                                               NaN
# 2                    NaN                                               NaN
# 3                    NaN                                               NaN
# 4                    NaN                                               NaN
#
#   server_location                hosting_isp  server_name  \
# 0             NaN                        NaN          NaN
# 1       Singapore              Incapsula Inc  istio-envoy
# 2   United States  Akamai Technologies, Inc.  AkamaiGHost
# 3          Russia  Yandex enterprise network  nginx/1.6.2
# 4   United States                 Google LLC          ESF
#
#                                    response_metadata
# 0                                                NaN
# 1  {"via": "kong/0.36-2-enterprise-edition", "x-v...
# 2  {"Date": "Wed, 18 Mar 2020 07:27:41 GMT", "Ser...
# 3  {"Date": "Mon, 23 Dec 2019 23:10:35 GMT", "Ser...
# 4  {"Date": "Thu, 07 Oct 2021 19:14:31 GMT", "Var...

# %%
api_df.dtypes
# Out:
# api_endpoint_id                                       int64
# api_id                                                int64
# api_vendor_id                                         int64
# api                                                  object
# request_id                                            int64
# method                                               object
# category                                             object
# parameters                                           object
# usage_base                                           object
# sample_response                                      object
# tagset                                               object
# authentication                                       object
# security_test_category                               object
# security_test_result (FALSE=Passed; TRUE=Failed)    float64
# server_location                                      object
# hosting_isp                                          object
# server_name                                          object
# response_metadata                                    object
# dtype: object

# %%
country_metric_df = pd.read_excel("../data/raw/nri_2021_dataset.xlsx", "NRI 2021 - results",
                      usecols = "B:C", skiprows=1)
                      
country_metric_df.head()
# Out:
#          Country  NRI score
# 0    Netherlands  82.061638
# 1         Sweden  81.567929
# 2        Denmark  81.235302
# 3  United States  81.089820
# 4        Finland  80.473263

# %%
country_metric_df.dtypes
# Out:
# Country       object
# NRI score    float64
# dtype: object

# %% [markdown]
# ## Combine df

# %%
# api_df_trial = pd.merge([api_df,country_metric_df])

# api_df.join(country_metric_df, how = "left", on='server_location')
api_df_trial = api_df.merge(country_metric_df, left_on = 'server_location', right_on = 'Country')
api_df_trial
# Out:
#      api_endpoint_id  api_id  api_vendor_id  \
# 0               2578    1148            440
# 1               2515    1118            412
# 2               2514    1118            412
# 3               2579    1148            440
# 4               2575    1147            439
# ..               ...     ...            ...
# 98              2699    1220            489
# 99              2730    1237            505
# 100             2796    1239            505
# 101             2795    1256            542
# 102             2684    1209            479
#
#                                                    api  request_id method  \
# 0                                         ANZ Products        8698    get
# 1                                    Text Analysis API        7726    get
# 2                                    Text Analysis API        7725   post
# 3                                         ANZ Products        8554    get
# 4                                        NAB Open APIs        8542    get
# ..                                                 ...         ...    ...
# 98                                   currencylayer API       26807    get
# 99                                          test api 2       19977    get
# 100                                               iAPI       22997    get
# 101  API for security test Adding random values to ...       23268    get
# 102                             Language Detection API       10178   post
#
#                       category  \
# 0            Finance & Banking
# 1            AI & Data Science
# 2            AI & Data Science
# 3            Finance & Banking
# 4            Finance & Banking
# ..                         ...
# 98           Finance & Banking
# 99   Health Science & Medicine
# 100      Business & Technology
# 101      Security & Technology
# 102      Information & Science
#
#                                             parameters usage_base  \
# 0                                                   {}       free
# 1                                                   {}       free
# 2                                                   {}       free
# 3    {"productId": "7c277163-1b71-d314-0f1f-b7e713b...       free
# 4                                           {"v": "1"}       free
# ..                                                 ...        ...
# 98                                   {"source": "USD"}       free
# 99                                                  {}       free
# 100                          {"match_id": "271145471"}       free
# 101                          {"match_id": "271145471"}       free
# 102                         {"q": "Mi nombre es Earl"}       free
#
#                                        sample_response  \
# 0    {"data":{"products":[{"additionalInformation":...
# 1    [{"id":"ar","name":"Ø§Ù„Ø¹Ø±Ø¨ÙŠØ©","englishNa...
# 2    {"text":"GNE is a good school, but talent nurt...
# 3    {"data":{"lastUpdated":"2019-08-22T22:57:35.61...
# 4    <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...
# ..                                                 ...
# 98   {"success":false,"error":{"code":105,"info":"A...
# 99   {\n  "userId": 1,\n  "id": 1,\n  "title": "del...
# 100  {"match_id":271145471,"barracks_status_dire":6...
# 101                    {"error":"rate limit exceeded"}
# 102  {"data":{"detections":[{"language":"fr","isRel...
#
#                                                 tagset authentication  \
# 0    links,eligibilityUri,brand,next,overviewUri,da...         header
# 1    englishName,nativeEncoding,name,id,latin,right...         header
# 2    severity,length,type,offset,sentence_index,tex...         header
# 3    isTailored,name,lendingRates,additionalValue,d...         header
# 4                                                  NaN         header
# ..                                                 ...            ...
# 98   success,info,error,code,success,code,code,code...          query
# 99   id,completed,title,userId,userId,id,id,id,id,i...           none
# 100  leagueid,firstblood_claimed,leaver_status,engi...         header
# 101  item_neutral,leagueid,gold_t,sen,assists,backp...         OAuth2
# 102  language,data,isReliable,confidence,detections...          query
#
#     security_test_category  security_test_result (FALSE=Passed; TRUE=Failed)  \
# 0                      NaN                                               NaN
# 1                      NaN                                               NaN
# 2                      NaN                                               NaN
# 3                      NaN                                               NaN
# 4                      NaN                                               NaN
# ..                     ...                                               ...
# 98                     NaN                                               NaN
# 99           SQL Injection                                               1.0
# 100                    NaN                                               NaN
# 101  Broken Authentication                                               0.0
# 102                    NaN                                               NaN
#
#     server_location                hosting_isp           server_name  \
# 0         Singapore              Incapsula Inc           istio-envoy
# 1         Singapore      Microsoft Corporation  Unavailable/Obscured
# 2         Singapore      Microsoft Corporation  Unavailable/Obscured
# 3         Singapore              Incapsula Inc           istio-envoy
# 4     United States  Akamai Technologies, Inc.           AkamaiGHost
# ..              ...                        ...                   ...
# 98            Spain           Cloudflare, Inc.            cloudflare
# 99            Spain           Cloudflare, Inc.            cloudflare
# 100           Spain           Cloudflare, Inc.            cloudflare
# 101           Spain           Cloudflare, Inc.            cloudflare
# 102       Lithuania                 RACKRAY-IV  Unavailable/Obscured
#
#                                      response_metadata        Country  \
# 0    {"via": "kong/0.36-2-enterprise-edition", "x-v...      Singapore
# 1    {"Date": "Mon, 23 Dec 2019 21:22:57 GMT", "Con...      Singapore
# 2    {"Date": "Mon, 23 Dec 2019 21:22:19 GMT", "Con...      Singapore
# 3    {"x-v": "1", "Date": "Wed, 18 Mar 2020 23:03:3...      Singapore
# 4    {"Date": "Wed, 18 Mar 2020 07:27:41 GMT", "Ser...  United States
# ..                                                 ...            ...
# 98   {"NEL": "{\"success_fraction\":0,\"report_to\"...          Spain
# 99   {"Age": "23190", "NEL": "{\"report_to\":\"cf-n...          Spain
# 100  {"NEL": "{\"report_to\":\"cf-nel\",\"max_age\"...          Spain
# 101  {"NEL": "{\"report_to\":\"cf-nel\",\"max_age\"...          Spain
# 102  {"Date": "Mon, 31 Aug 2020 18:34:24 GMT", "Con...      Lithuania
#
#      NRI score
# 0    80.014421
# 1    80.014421
# 2    80.014421
# 3    80.014421
# 4    81.089820
# ..         ...
# 98   69.942859
# 99   69.942859
# 100  69.942859
# 101  69.942859
# 102  65.319616
#
# [103 rows x 20 columns]

# %%
# Sanity Check to see if there are columns that do not have NRI score
api_df_trial[api_df_trial['NRI score'].isnull()]
# Out:
# Empty DataFrame
# Columns: [api_endpoint_id, api_id, api_vendor_id, api, request_id, method, category, parameters, usage_base, sample_response, tagset, authentication, security_test_category, security_test_result (FALSE=Passed; TRUE=Failed), server_location, hosting_isp, server_name, response_metadata, Country, NRI score]
# Index: []
